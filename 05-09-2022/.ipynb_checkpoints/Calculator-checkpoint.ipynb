# %%
import tkinter as tk
from tkinter import ttk

main = tk.Tk()
main.title("Calculate")

expression = ""
 

def press(num):
    global expression
 
    expression = expression + str(num)
 
    equation.set(expression)
 
 

def equalpress():
    try:
 
        global expression
        total = str(eval(expression))
 
        equation.set(total)
 

        expression = ""
 
    except:
 
        equation.set(" error ")
        expression = ""
 
 
def clear():
    global expression
    expression = ""
    equation.set("")


# Row1
calculate_input = ttk.Entry(main)
calculate_input.grid(row=0,column=0, columnspan =4, sticky='we')

# Row2
btn1 = ttk.Button(main, text='1', command= callback)
btn2 = ttk.Button(main, text='2', command= callback)
btn3 = ttk.Button(main, text='3', command= callback)
btn_pls = ttk.Button(main, text='+', command= callback)

btn1.grid(row=1, column=0)
btn2.grid(row=1, column=1)
btn3.grid(row=1, column=2)
btn_pls.grid(row=1, column=3)

# Row3
btn4 = ttk.Button(main, text='4', command= callback)
btn5 = ttk.Button(main, text='5', command= callback)
btn6 = ttk.Button(main, text='6', command= callback)
btn_mn = ttk.Button(main, text='-', command= callback)

btn4.grid(row=2, column=0)
btn5.grid(row=2, column=1)
btn6.grid(row=2, column=2)
btn_mn.grid(row=2, column=3)

# Row4
btn7 = ttk.Button(main, text='7', command= callback)
btn8 = ttk.Button(main, text='8', command= callback)
btn9 = ttk.Button(main, text='9', command= callback)
btn_time = ttk.Button(main, text='*', command= callback)

btn7.grid(row=3, column=0)
btn8.grid(row=3, column=1)
btn9.grid(row=3, column=2)
btn_time.grid(row=3, column=3)

# Row5
btn0 = ttk.Button(main, text='0', command= callback)
btn_clear = ttk.Button(main, text='Clear', command= callback)
btn_equal = ttk.Button(main, text='=', command= callback)
btn_div = ttk.Button(main, text='/', command= callback)

btn0.grid(row=4, column=0)
btn_clear.grid(row=4, column=1)
btn_equal.grid(row=4, column=2)
btn_div.grid(row=4, column=3)

# Row6
btn_dot = ttk.Button(main, text='.', command=callback)

btn_dot.grid(row=5, column=0)

main.mainloop()
