# %%
myTempList = {}

def add_chitieu(myTempList):
    print('*** Chức năng thêm chi tiêu ***')
    name_chitieu = input('Nhập tên chi tiêu: ')
    gia_tri = input('Giá trị: ')
    date_chitieu = input('Nhập ngày: ')
    if name_chitieu in myTempList:
        print(f'Chi tiêu với tên {name_chitieu} đã tồn tại.')
    else:
        myTempList[name_chitieu] = {
            'gia' : gia_tri,
            'ngay' : date_chitieu
        }
        print(f'thêm chi tiêu thành công với tên {name_chitieu}.')

def remove_chitieu(myTempList):
    print('***Chức năng xóa chi tiêu***')
    name_chitieu = input('Nhập tên chi tiêu cần xóa: ')
    if name_chitieu not in myTempList:
        print('Chi tiêu không tồn tại')
        return
    del myTempList[name_chitieu]
    print(f'Xóa thành công chi tiêu với tên {name_chitieu}')

def show_chitieu(myTempList):
    print('***Chức năng hiển thị danh sách chi tiêu***')
    for name_chitieu, info in myTempList.items():
        print(f'Tên: {name_chitieu}.  Giá: {info["gia"]}.  Ngày: {info["ngay"]}')

def find_chitieu(myTempList): 
    print('***Chức năng tìm kiếm chi tiêu***')
    name_chitieu = input('Nhập tên chi tiêu mà bạn muốn tìm kiếm: ')
    if name_chitieu not in myTempList:
        print('Chi tiêu không tồn tại')
        return 
    my_chitieu = myTempList.get(name_chitieu)
    print(f'Chi tiêu "{name_chitieu}" có giá trị là: {my_chitieu["gia"]} ngày: {my_chitieu["ngay"]}. ')

while True:
    print('=== Chương trình quản lý chi tiêu ===')
    print('Chọn thao tác mà bạn muốn: ')
    print('1. Thêm chi tiêu')
    print('2. Xóa sản phẩm')
    print('3. Hiển thị danh sách chi tiêu')
    print('4. Tìm chi tiêu')
    print('5. Thoát')
    chose = input('Nhập thao tác mà bạn muốn(1-5): ')
    if chose == '1':
        add_chitieu(myTempList)
    elif chose == '2':
        remove_chitieu(myTempList)
    elif chose == '3':
        show_chitieu(myTempList)
    elif chose == '4':
        find_chitieu(myTempList)
    elif chose == '5':
        print('Hẹn gặp lại lần sau')
        break
    else:
        print('Thao tác không tồn tại')
# Out:
# === Chương trình quản lý chi tiêu ===
# Chọn thao tác mà bạn muốn:
# 1. Thêm chi tiêu
# 2. Xóa sản phẩm
# 3. Hiển thị danh sách chi tiêu
# 4. Tìm chi tiêu
# 5. Thoát
# Nhập thao tác mà bạn muốn(1-5): 1
# *** Chức năng thêm chi tiêu ***
# Nhập tên chi tiêu: phone
# Giá trị: 120000 vnđ
# Nhập ngày: 10/01/2022
# thêm chi tiêu thành công với tên phone.
# === Chương trình quản lý chi tiêu ===
# Chọn thao tác mà bạn muốn:
# 1. Thêm chi tiêu
# 2. Xóa sản phẩm
# 3. Hiển thị danh sách chi tiêu
# 4. Tìm chi tiêu
# 5. Thoát
# Nhập thao tác mà bạn muốn(1-5): 1
# *** Chức năng thêm chi tiêu ***
# Nhập tên chi tiêu: food
# Giá trị: 200000 vnđ
# Nhập ngày: 12/01/2022
# thêm chi tiêu thành công với tên food.
# === Chương trình quản lý chi tiêu ===
# Chọn thao tác mà bạn muốn:
# 1. Thêm chi tiêu
# 2. Xóa sản phẩm
# 3. Hiển thị danh sách chi tiêu
# 4. Tìm chi tiêu
# 5. Thoát
# Nhập thao tác mà bạn muốn(1-5): 3
# ***Chức năng hiển thị danh sách chi tiêu***
# ...
