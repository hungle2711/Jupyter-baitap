# %%
import pandas as pd
import numpy as np
# data = pd.read_csv('FoodPrice_in_Turkey.csv',
#                    header=0,encoding = 'ISO-8859-1')
df = pd.read_csv('C:\\Users\\hungu\\Jupyter baitap\\DATA\\DA - Datasets\\FoodPrice_in_Turkey.csv', header=0, encoding="ISO-8859-1")
df
print('*'*20, 'Nhập dữ liệu thành công', '*'*20)
display(df)
# Out:
# ******************** Nhập dữ liệu thành công ********************
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %%
print(df.shape)
# số hàng
print(df.shape[0])
# số cột
print(df.shape[1])
# Out:
# (7381, 8)
# 7381
# 8

# %%
df.columns
# Out:
# Index(['Place', 'ProductId', 'ProductName', 'UmId', 'UmName', 'Month', 'Year',
#        'Price'],
#       dtype='object')

# %%
# Đổi tên của cột
df.columns = ['Địa điểm', 'Mã SP', 'Tên SP', 'Đơn vị', 'Tên đơn vị', 'Tháng', 'Năm', 'Giá']
df
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm      Giá
# 0         5  2013   4.4920
# ...

# %% [markdown]
# Đổi tên

# %%
# đổi tên chỉ 1 cột
df.rename(columns = {'Địa điểm':'Place'}, inplace = True)
df
# Out:
#                  Place  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm      Giá
# 0         5  2013   4.4920
# ...

# %% [markdown]
# Thêm Cột

# %%
df['Tên cột mới'] = 0
df
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3000                  Dưa hấu       5         KG
# 1              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng  Chiết khấu (%)      Giá  Tên cột mới
# ...

# %%
# chèn cột sau cột
df.insert(8,'Chiết khấu (%)', 0.2)
df
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3000                  Dưa hấu       5         KG
# 1              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng  Chiết khấu (%)      Giá
# ...

# %%
df.insert(7,'Số lượng', 50)
df
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu (%)  Tên cột mới
# ...

# %%
df.rename(columns = {'Tên cột mới':'Tổng'}, inplace = True)
df
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu (%)  Tổng
# ...

# %%
df['Tổng'] = df['Giá'] * df['Số lượng'] * (100-df['Chiết khấu (%)'])/100
df
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu (%)        Tổng
# ...

# %% [markdown]
# THÊM MỘT DÒNG VÀO CUỐI BẢNG df.loc[chỉ số của dòng]=[...]

# %%
df.loc[df.shape[0]] = ['Sài Gòn', 3000, 'Dưa hấu', 5, 'KG',10,10,2022,50.000,10,np.NaN]
df
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu (%)        Tổng
# ...

# %% [markdown]
# THÊM VÀO ĐẦU BẢNG

# %%
# df.loc[-1] = ['Hà Nội', 3000, 'Dưa hấu', 5, 'KG',10,10,2022,50.000,10,np.NaN]
df.index = df.index +1
df = df.sort_index()
df
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3000                  Dưa hấu       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu (%)        Tổng
# ...

# %%
df.loc[-1] = df.loc[0]
df.loc[0] = ['Đà Nẵng', 3002, 'Mỳ Quảng', 5, 'Tô',10,2022,10,50.000,10,np.NaN]
df = df.sort_index()
df.index = df.index +1
df
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3000                  Dưa hấu       5         KG
# 1              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu (%)        Tổng
# ...

# %% [markdown]
# XÓA CỘT del df['Tên cột'] hoặc df.pop('')

# %%
del df['Tổng']
df
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3000                  Dưa hấu       5         KG
# 1              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu (%)
# ...

# %%
df.rename(columns = {'Tên cột mới':'Tổng'}, inplace = True)
df['Tổng'] = df['Giá'] * df['Số lượng'] * (100-df['Chiết khấu (%)'])/100
df
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3000                  Dưa hấu       5         KG
# 1              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng  Chiết khấu (%)      Giá          Tổng
# ...

# %%
data = df
data1 = data.pop('Tổng')
print(data1)
# Out:
# 0       100897.80000
# 1          499.00000
# 2          224.15080
# 3          228.47214
# 4          238.84635
#             ...
# 7379      2450.96824
# 7380      2536.65153
# 7381      2584.74515
# 7382      2575.19429
# 7383    100897.80000
# Name: Tổng, Length: 7384, dtype: float64

# %%
df
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3000                  Dưa hấu       5         KG
# 1              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng  Chiết khấu (%)      Giá
# ...

# %% [markdown]
# Xóa dòng df.drop(cs, axis=0, inplace = True/False)

# %%
data = df.drop(7383, axis=0)
data
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3000                  Dưa hấu       5         KG
# 1              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm  Số lượng  Chiết khấu (%)      Giá
# ...

# %% [markdown]
# XÓA NHIỀU DÒNG HAY NHIỀU CỘT THÌ DÙNG [...]
